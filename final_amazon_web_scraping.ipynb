# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {"User-Agent": ""}#add your user agent 
url = "https://www.amazon.in/s?k=mobiles&crid=2F49SZUME2VJO&sprefix=mobiles%2Caps%2C292&ref=nb_sb_noss_1"
r = requests.get(url,headers=headers)
soup  = BeautifulSoup(r.content,"html.parser")
links = soup.find_all("a",attrs={'class':"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"})

ls = []
for i in links:
    ls.append("https://www.amazon.in"+i.get('href'))
name=[]
price=[]
rating=[]
stock=[]
stars=[]

# %%
def get_name(new_soup):
    try:
        n = new_soup.find('span',attrs={"id":"productTitle"}).text.strip()
    except AttributeError:
        n=''
    return n

def get_price(new_soup):
    try:
        x = new_soup.find('span',attrs={'class':"a-price-whole"}).text
        n = '₹'+x+'00'
    except AttributeError:
        n = ''
    return n

def get_rating(new_soup):
    try:
        n = new_soup.find('span',attrs={'id':"acrCustomerReviewText"}).text
    except AttributeError:
        n = ''
    return n

def get_availability(new_soup):
    try:
        n = new_soup.find('div',attrs={'id':"availability"}).find('span').text.strip()
    except AttributeError:
        n = ''
    return n

def get_stars(new_soup):
    try:
        n = new_soup.find('span',attrs={'data-hook':"rating-out-of-text"}).text
    except:
        n = ''
    return n

# %%
for i in ls:
    new_page = requests.get(i,headers=headers)
    new_soup = BeautifulSoup(new_page.content,'html.parser')
    name.append(get_name(new_soup))
    price.append(get_price(new_soup))
    rating.append(get_rating(new_soup))
    stock.append(get_availability(new_soup))
    stars.append(get_stars(new_soup))

# %%
#creating a dataframe
data = {'Name':name,
'Price':price,
'CustomerReviewText':rating,
'Availability':stock,
'Ratings':stars}

df = pd.DataFrame(data)

#storing extracted data in csv file
df.to_csv('book1.csv',header=True,index=False)

# %%
df
# Out:
#                                                  Name         Price  \
# 0   Samsung Galaxy M13 (Stardust Brown, 6GB, 128GB...    ₹13,999.00
# 1   Samsung Galaxy M33 5G (Mystique Green, 8GB, 12...    ₹20,499.00
# 2   Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...     ₹7,999.00
# 3   Mobile Phone, Mini Lightweight 5MP Rear Camera...     ₹9,484.00
# 4   Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...     ₹6,999.00
# 5   OnePlus 10 Pro 5G (Emerald Forest, 12GB RAM, 2...    ₹66,999.00
# 6   iQOO 9 Pro 5G (Legend, 8GB RAM, 256GB Storage)...    ₹57,990.00
# 7   Samsung Galaxy S22 Ultra 5G (Phantom Black, 12...  ₹1,08,999.00
# 8   OnePlus 10T 5G (Moonstone Black, 8GB RAM, 128G...    ₹44,999.00
# 9   Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...     ₹6,499.00
# 10  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...    ₹18,999.00
# 11  Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...     ₹9,499.00
# 12  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...    ₹18,999.00
# 13  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...    ₹11,990.00
# 14  Redmi Note 11 Pro + 5G (Mirage Blue, 6GB RAM, ...    ₹19,999.00
# 15  Redmi Note 11T 5G (Matte Black, 6GB RAM, 128GB...    ₹17,999.00
# 16  OPPO A74 5G (Fantastic Purple,6GB RAM,128GB St...    ₹14,990.00
# 17  Samsung Galaxy M13 (Aqua Green, 4GB, 64GB Stor...    ₹11,999.00
# 18  Samsung Galaxy M32 Prime Edition (Light Blue, ...    ₹15,499.00
# 19  realme narzo 50i (Carbon Black, 4GB RAM+64GB S...     ₹8,999.00
# 20  realme narzo 50i (Mint Green, 4GB RAM+64GB Sto...     ₹8,999.00
# 21  OPPO A74 5G (Fluid Black, 6GB RAM, 128GB Stora...    ₹14,990.00
# 22  realme narzo 50i (Carbon Black, 2GB RAM+32GB S...     ₹7,499.00
# 23  Samsung Galaxy M13 (Stardust Brown, 6GB, 128GB...    ₹13,999.00
# 24  Maplin 5G S30 (8GB RAM / 128 GB Internal Memor...    ₹14,990.00
# 25  Redmi Note 11 (Space Black, 6GB RAM, 64GB Stor...    ₹13,499.00
# 26  Irusu PlayVR Premium VR Headset Without Remote...     ₹2,097.00
# 27  (Renewed) ASUS ROG Phone 2 (ZS660KL) Smartphon...    ₹24,999.00
# 28  Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB S...    ₹14,999.00
# 29  iQOO Z6 44W (Raven Black, 8GB RAM, 128GB Storage)    ₹15,999.00
# 30  Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...     ₹6,499.00
# 31  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...     ₹6,999.00
# 32  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...    ₹18,999.00
# 33  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...     ₹7,999.00
#
#    CustomerReviewText                         Availability       Ratings
# 0      13,275 ratings                             In stock    4 out of 5
# 1      18,851 ratings                             In stock  4.1 out of 5
# 2     305,846 ratings                             In stock  4.2 out of 5
# 3                      Usually dispatched in 10 to 11 days
# 4     305,846 ratings                            In stock.  4.2 out of 5
# 5       4,721 ratings                             In stock  4.2 out of 5
# 6       1,166 ratings                                       4.1 out of 5
# 7       1,294 ratings                             In stock  4.4 out of 5
# 8       2,345 ratings                             In stock  4.2 out of 5
# 9       4,448 ratings                             In stock    4 out of 5
# 10     97,660 ratings                            In stock.  4.3 out of 5
# 11      9,579 ratings                             In stock  3.9 out of 5
# 12     97,660 ratings                                       4.3 out of 5
# 13     57,682 ratings                            In stock.  4.2 out of 5
# 14     22,812 ratings                            In stock.  3.8 out of 5
# 15     28,393 ratings                             In stock  4.1 out of 5
# 16     31,216 ratings                             In stock  4.2 out of 5
# 17     13,275 ratings                             In stock    4 out of 5
# 18     53,491 ratings                                       4.1 out of 5
# 19     28,281 ratings                            In stock.    4 out of 5
# 20     28,281 ratings                                         4 out of 5
# 21     31,216 ratings                             In stock  4.2 out of 5
# 22     28,281 ratings                             In stock    4 out of 5
# 23     13,275 ratings                             In stock    4 out of 5
# 24           1 rating                             In stock    1 out of 5
# 25     46,173 ratings                                       4.1 out of 5
# 26           1 rating                            In stock.    5 out of 5
# 27           1 rating                            In stock.    4 out of 5
# 28    215,520 ratings                             In stock  4.2 out of 5
# 29     15,835 ratings                            In stock.  4.1 out of 5
# 30      4,448 ratings                                         4 out of 5
# 31    305,846 ratings                             In stock  4.2 out of 5
# 32     97,660 ratings                            In stock.  4.3 out of 5
# 33    305,846 ratings                             In stock  4.2 out of 5
